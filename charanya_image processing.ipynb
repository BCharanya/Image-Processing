# %% [markdown]
# ### Image Processing

# %%
import os
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
fort=os.listdir('C:/Users/Dell/dataset/fort thitipong sengngai')
gulf=os.listdir('C:/Users/Dell/dataset/gulf kanawut')
jeff=os.listdir('C:/Users/Dell/dataset/jeff satur')

# %%
limit = 20
fort_images =[None]*limit
j=0
for i in fort:
    if(j<limit):
        fort_images[j]=imread("C:/Users/Dell/dataset/fort thitipong sengngai/"+i)
        j+=1
    else:
        break

# %%
limit = 20
gulf_images =[None]*limit
j=0
for i in gulf:
    if(j<limit):
        gulf_images[j]=imread("C:/Users/Dell/dataset/gulf kanawut/"+i)
        j+=1
    else:
        break

# %%
limit = 20
jeff_images =[None]*limit
j=0
for i in jeff:
    if(j<limit):
        jeff_images[j]=imread("C:/Users/Dell/dataset/jeff satur/"+i)
        j+=1
    else:
        break

# %% [markdown]
# ### Displaying Images

# %%
imshow(fort_images[11])

# %%
imshow(gulf_images[12])

# %%
imshow(jeff_images[0])

# %%
fort_gray =[None]*limit
j=0

for i in fort:
    if(j<limit):
        fort_gray[j] = rgb2gray(fort_images[j])
        j+=1
    else:
        break

# %%
imshow(fort_gray[4])

# %%
gulf_gray =[None]*limit
j=0

for i in gulf:
    if(j<limit):
        gulf_gray[j] = rgb2gray(gulf_images[j])
        j+=1
    else:
        break

# %%
imshow(gulf_gray[7])

# %%
jeff_gray =[None]*limit
j=0

for i in jeff:
    if(j<limit):
        jeff_gray[j] = rgb2gray(jeff_images[j])
        j+=1
    else:
        break

# %%
imshow(jeff_gray[2])

# %%
for j in range(20):
    fort=fort_gray[j]
    fort_gray[j]=resize(fort,(512,512))

# %%
for j in range(20):
    gulf=gulf_gray[j]
    gulf_gray[j]=resize(gulf,(512,512))

# %%
for j in range(20):
    jeff=jeff_gray[j]
    jeff_gray[j]=resize(jeff,(512,512))

# %%
imshow(fort_gray[4])

# %%
imshow(gulf_gray[7])

# %%
imshow(jeff_gray[2])

# %%
len_of_images_fort=len(fort_gray)
len_of_images_fort
# Out:
# 20

# %%
images_size_fort=fort_gray[4].shape
images_size_fort
# Out:
# (512, 512)

# %%
flatten_size_fort=images_size_fort[0]*images_size_fort[1]
flatten_size_fort
# Out:
# 262144

# %%
for i in range(len_of_images_fort):
    fort_gray[i]=np.ndarray.flatten(fort_gray[i]).reshape(flatten_size_fort,1)
fort_gray=np.dstack(fort_gray)
fort_gray.shape
# Out:
# (262144, 1, 20)

# %%
fort_gray=np.rollaxis(fort_gray,axis=2,start=0)
fort_gray.shape
# Out:
# (20, 262144, 1)

# %%
fort_gray=fort_gray.reshape(len_of_images_fort,flatten_size_fort)
fort_gray.shape
# Out:
# (20, 262144)

# %%
fort_data=pd.DataFrame(fort_gray)
fort_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.970621  0.964621  0.959022  0.956577  0.960836  0.961679  0.965803
# 1   0.632512  0.632512  0.632512  0.632100  0.631137  0.630695  0.631102
# 2   0.537216  0.534549  0.533473  0.535530  0.541159  0.540090  0.540792
# 3   0.049574  0.049574  0.049574  0.049574  0.049574  0.049513  0.045974
# 4   0.067836  0.067836  0.067836  0.067836  0.067836  0.067836  0.067836
# 5   0.716144  0.723056  0.691942  0.645210  0.699597  0.847530  0.889405
# 6   0.710696  0.710696  0.714617  0.714617  0.714617  0.716776  0.717386
# 7   0.861511  0.861511  0.861511  0.861511  0.861511  0.861511  0.861511
# 8   0.796376  0.796376  0.796376  0.796376  0.796376  0.796376  0.796376
# 9   0.815671  0.820098  0.824274  0.824985  0.820987  0.819340  0.819340
# 10  0.471285  0.471591  0.469783  0.468484  0.468745  0.468985  0.468985
# 11  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ...

# %%
fort_data["label"]="Fort"
fort_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.970621  0.964621  0.959022  0.956577  0.960836  0.961679  0.965803
# 1   0.632512  0.632512  0.632512  0.632100  0.631137  0.630695  0.631102
# 2   0.537216  0.534549  0.533473  0.535530  0.541159  0.540090  0.540792
# 3   0.049574  0.049574  0.049574  0.049574  0.049574  0.049513  0.045974
# 4   0.067836  0.067836  0.067836  0.067836  0.067836  0.067836  0.067836
# 5   0.716144  0.723056  0.691942  0.645210  0.699597  0.847530  0.889405
# 6   0.710696  0.710696  0.714617  0.714617  0.714617  0.716776  0.717386
# 7   0.861511  0.861511  0.861511  0.861511  0.861511  0.861511  0.861511
# 8   0.796376  0.796376  0.796376  0.796376  0.796376  0.796376  0.796376
# 9   0.815671  0.820098  0.824274  0.824985  0.820987  0.819340  0.819340
# 10  0.471285  0.471591  0.469783  0.468484  0.468745  0.468985  0.468985
# 11  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ...

# %%
len_of_images_gulf=len(gulf_gray)
len_of_images_gulf
# Out:
# 20

# %%
images_size_gulf=gulf_gray[3].shape
images_size_gulf
# Out:
# (512, 512)

# %%
flatten_size_gulf=images_size_gulf[0]*images_size_gulf[1]
flatten_size_gulf
# Out:
# 262144

# %%
for i in range(len_of_images_gulf):
    gulf_gray[i]=np.ndarray.flatten(gulf_gray[i]).reshape(flatten_size_gulf,1)
gulf_gray=np.dstack(gulf_gray)
gulf_gray.shape
# Out:
# (262144, 1, 20)

# %%
gulf_gray=np.rollaxis(gulf_gray,axis=2,start=0)
gulf_gray.shape
# Out:
# (20, 262144, 1)

# %%
gulf_gray=gulf_gray.reshape(len_of_images_gulf,flatten_size_gulf)
gulf_gray.shape
# Out:
# (20, 262144)

# %%
gulf_data=pd.DataFrame(gulf_gray)
gulf_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.868281  0.860891  0.862361  0.869021  0.863135  0.863118  0.863117
# 1   0.264323  0.250485  0.269906  0.282017  0.273201  0.243244  0.208308
# 2   0.862814  0.860327  0.855150  0.851978  0.852321  0.854569  0.855154
# 3   0.924084  0.924084  0.924084  0.924576  0.927997  0.928005  0.928004
# 4   0.746882  0.746882  0.746882  0.746882  0.746882  0.746882  0.746882
# 5   0.437471  0.437621  0.439557  0.439355  0.437105  0.439246  0.442811
# 6   0.076879  0.112541  0.143122  0.175046  0.215526  0.261130  0.291806
# 7   0.808861  0.808861  0.808861  0.809245  0.811916  0.811922  0.811922
# 8   0.906301  0.908041  0.906081  0.900350  0.902260  0.902266  0.902267
# 9   0.860671  0.860943  0.862044  0.863011  0.862837  0.862202  0.862180
# 10  0.545720  0.546780  0.548893  0.549900  0.546989  0.546135  0.548048
# 11  0.382361  0.397675  0.442216  0.521885  0.399171  0.410489  0.520451
# ...

# %%
gulf_data["label"]="Gulf"
gulf_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.868281  0.860891  0.862361  0.869021  0.863135  0.863118  0.863117
# 1   0.264323  0.250485  0.269906  0.282017  0.273201  0.243244  0.208308
# 2   0.862814  0.860327  0.855150  0.851978  0.852321  0.854569  0.855154
# 3   0.924084  0.924084  0.924084  0.924576  0.927997  0.928005  0.928004
# 4   0.746882  0.746882  0.746882  0.746882  0.746882  0.746882  0.746882
# 5   0.437471  0.437621  0.439557  0.439355  0.437105  0.439246  0.442811
# 6   0.076879  0.112541  0.143122  0.175046  0.215526  0.261130  0.291806
# 7   0.808861  0.808861  0.808861  0.809245  0.811916  0.811922  0.811922
# 8   0.906301  0.908041  0.906081  0.900350  0.902260  0.902266  0.902267
# 9   0.860671  0.860943  0.862044  0.863011  0.862837  0.862202  0.862180
# 10  0.545720  0.546780  0.548893  0.549900  0.546989  0.546135  0.548048
# 11  0.382361  0.397675  0.442216  0.521885  0.399171  0.410489  0.520451
# ...

# %%
len_of_images_jeff=len(jeff_gray)
len_of_images_jeff
# Out:
# 20

# %%
images_size_jeff=jeff_gray[3].shape
images_size_jeff
# Out:
# (512, 512)

# %%
flatten_size_jeff=images_size_jeff[0]*images_size_jeff[1]
flatten_size_jeff
# Out:
# 262144

# %%
for i in range(len_of_images_jeff):
    jeff_gray[i]=np.ndarray.flatten(jeff_gray[i]).reshape(flatten_size_jeff,1)

# %%
jeff_gray=np.dstack(jeff_gray)
jeff_gray.shape
# Out:
# (262144, 1, 20)

# %%
jeff_gray=np.rollaxis(jeff_gray,axis=2,start=0)
jeff_gray.shape
# Out:
# (20, 262144, 1)

# %%
jeff_gray=jeff_gray.reshape(len_of_images_jeff,flatten_size_jeff)
jeff_gray.shape
# Out:
# (20, 262144)

# %%
jeff_data=pd.DataFrame(jeff_gray)
jeff_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.554433  0.554433  0.554433  0.554433  0.553699  0.552300  0.550719
# 1   0.461541  0.464114  0.465465  0.464415  0.459694  0.459567  0.457903
# 2   0.496713  0.642170  0.637760  0.644622  0.627222  0.645970  0.645971
# 3   0.423144  0.426315  0.423077  0.424758  0.427102  0.429368  0.428940
# 4   0.022955  0.022527  0.023505  0.024483  0.027061  0.029937  0.031787
# 5   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 6   0.671836  0.674685  0.680323  0.684862  0.688083  0.696816  0.704559
# 7   0.636582  0.646017  0.645139  0.638810  0.643296  0.652418  0.653861
# 8   0.546626  0.542752  0.535591  0.528021  0.525341  0.519366  0.513871
# 9   0.876980  0.878451  0.880902  0.884333  0.885313  0.888745  0.886294
# 10  0.372252  0.480321  0.479812  0.472873  0.464172  0.470365  0.469017
# 11  0.656463  0.657693  0.654027  0.655315  0.649659  0.651253  0.649198
# ...

# %%
jeff_data["label"]="Jeff"
jeff_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.554433  0.554433  0.554433  0.554433  0.553699  0.552300  0.550719
# 1   0.461541  0.464114  0.465465  0.464415  0.459694  0.459567  0.457903
# 2   0.496713  0.642170  0.637760  0.644622  0.627222  0.645970  0.645971
# 3   0.423144  0.426315  0.423077  0.424758  0.427102  0.429368  0.428940
# 4   0.022955  0.022527  0.023505  0.024483  0.027061  0.029937  0.031787
# 5   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 6   0.671836  0.674685  0.680323  0.684862  0.688083  0.696816  0.704559
# 7   0.636582  0.646017  0.645139  0.638810  0.643296  0.652418  0.653861
# 8   0.546626  0.542752  0.535591  0.528021  0.525341  0.519366  0.513871
# 9   0.876980  0.878451  0.880902  0.884333  0.885313  0.888745  0.886294
# 10  0.372252  0.480321  0.479812  0.472873  0.464172  0.470365  0.469017
# 11  0.656463  0.657693  0.654027  0.655315  0.649659  0.651253  0.649198
# ...

# %%
actor_1=pd.concat([fort_data,gulf_data])
actor=pd.concat([actor_1,jeff_data])
actor
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.970621  0.964621  0.959022  0.956577  0.960836  0.961679  0.965803
# 1   0.632512  0.632512  0.632512  0.632100  0.631137  0.630695  0.631102
# 2   0.537216  0.534549  0.533473  0.535530  0.541159  0.540090  0.540792
# 3   0.049574  0.049574  0.049574  0.049574  0.049574  0.049513  0.045974
# 4   0.067836  0.067836  0.067836  0.067836  0.067836  0.067836  0.067836
# 5   0.716144  0.723056  0.691942  0.645210  0.699597  0.847530  0.889405
# 6   0.710696  0.710696  0.714617  0.714617  0.714617  0.716776  0.717386
# 7   0.861511  0.861511  0.861511  0.861511  0.861511  0.861511  0.861511
# 8   0.796376  0.796376  0.796376  0.796376  0.796376  0.796376  0.796376
# 9   0.815671  0.820098  0.824274  0.824985  0.820987  0.819340  0.819340
# 10  0.471285  0.471591  0.469783  0.468484  0.468745  0.468985  0.468985
# 11  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ...

# %%
from sklearn.utils import shuffle
Thai_indexed=shuffle(actor).reset_index()
Thai_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       0  0.970621  0.964621  0.959022  0.956577  0.960836  0.961679
# 1       4  0.746882  0.746882  0.746882  0.746882  0.746882  0.746882
# 2      14  0.316654  0.385960  0.437210  0.463640  0.469525  0.474695
# 3      13  0.756188  0.755746  0.761526  0.761943  0.758019  0.758013
# 4      19  0.530916  0.530916  0.530916  0.530424  0.527003  0.526995
# 5      11  0.656463  0.657693  0.654027  0.655315  0.649659  0.651253
# 6       8  0.906301  0.908041  0.906081  0.900350  0.902260  0.902266
# 7       7  0.808861  0.808861  0.808861  0.809245  0.811916  0.811922
# 8      16  0.325587  0.329750  0.332345  0.330232  0.322791  0.328680
# 9      18  0.812062  0.812062  0.812062  0.812062  0.812062  0.812062
# 10     12  0.841188  0.841188  0.841188  0.841282  0.841665  0.842128
# 11     13  0.790461  0.792520  0.794114  0.795659  0.790557  0.794003
# ...

# %%
Thai_actors=Thai_indexed.drop(['index'],axis=1)
Thai_actors
x=Thai_actors.values[:,:-1]
y=Thai_actors.values[:,-1]

# %%
x
# Out:
# array([[0.970621133241098, 0.9646205863603945, 0.9590218125263006, ...,
#         0.8870503518821322, 0.8959841668586094, 0.8937853594913865],
#        [0.746881960784314, 0.746881960784314, 0.746881960784314, ...,
#         0.49727176991835254, 0.5029047822524546, 0.5037447714126136],
#        [0.31665447280857417, 0.38596022735052016, 0.43721000822140565,
#         ..., 0.13017625226521526, 0.13205985091333172,
#         0.12325746355933224],
#        ...,
#        [0.5457200849941115, 0.5467803298859485, 0.5488932877534893, ...,
#         0.16804231997492958, 0.16349824285726672, 0.1547958879858387],
#        [0.9240835294117646, 0.9240835294117646, 0.9240835294117646, ...,
#         0.8873275143488142, 0.8831026294723352, 0.880680771990865],
#        [0.9459690196078432, 0.9459690196078432, 0.9459690196078432, ...,
#         0.8526508079491149, 0.849361106046823, 0.8493460986184314]],
#       dtype=object)

# %%
y
# Out:
# array(['Fort', 'Gulf', 'Jeff', 'Fort', 'Gulf', 'Jeff', 'Gulf', 'Gulf',
#        'Fort', 'Fort', 'Fort', 'Gulf', 'Jeff', 'Jeff', 'Jeff', 'Fort',
#        'Fort', 'Gulf', 'Jeff', 'Jeff', 'Jeff', 'Gulf', 'Jeff', 'Fort',
#        'Fort', 'Jeff', 'Jeff', 'Jeff', 'Fort', 'Fort', 'Fort', 'Gulf',
#        'Gulf', 'Gulf', 'Gulf', 'Jeff', 'Fort', 'Fort', 'Fort', 'Jeff',
#        'Fort', 'Fort', 'Jeff', 'Jeff', 'Fort', 'Jeff', 'Gulf', 'Jeff',
#        'Gulf', 'Gulf', 'Gulf', 'Jeff', 'Gulf', 'Fort', 'Gulf', 'Gulf',
#        'Fort', 'Gulf', 'Gulf', 'Jeff'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm
clf=svm.SVC()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
y_pred
# Out:
# array(['Fort', 'Fort', 'Fort', 'Fort', 'Fort', 'Gulf', 'Gulf', 'Gulf',
#        'Fort', 'Fort', 'Jeff', 'Fort'], dtype=object)

# %%
for i in (np.random.randint(0,6,4)):
    predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label:{0}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.4166666666666667

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0, 0],
#        [1, 2, 1],
#        [4, 1, 0]], dtype=int64)
